# %%
import os
import PIL
import exifread
import lxml.etree as etree
import numpy as np
import pandas as pd
import slidingwindow
import skimage.color
import skimage.io
import cv2

from PIL import Image
import rasterio

# %%
with rasterio.open("/home/camarada/Documents/CDE/3-semester/DeepLearning/ReforesTree/dataset/wwf_ecuador/RGB Orthomosaics/Carlos Vera Arteaga RGB.tif") as src:
    img = src.read()
    print(img.shape)
    print(src.crs)
    print(src.bounds)
    print(src.is_tiled())
# Out:
# (4, 15053, 15297)
# EPSG:4326
# BoundingBox(left=-79.59391966252713, bottom=-1.2022688083952422, right=-79.59248743654082, top=-1.2008502452865422)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 print(src.crs)
#       5 print(src.bounds)
# ----> 6 print(src.tiles())
#
# AttributeError: 'DatasetReader' object has no attribute 'tiles'

# %%
import pandas as pd

# %%
dff = pd.read_csv("/home/camarada/Documents/CDE/3-semester/DeepLearning/ReforesTree/dataset/mapping/final_dataset.csv")

# %%
sorted(dff['name'].unique())
# Out:
# ['Achotillo',
#  'Balsa',
#  'Bariable',
#  'Cacao',
#  'Caoba',
#  'Cedro',
#  'Fernan Sanchez',
#  'Fruta de Pan',
#  'Guaba',
#  'Guachapeli',
#  'Guanabana',
#  'Guayacan',
#  'Laurel',
#  'Limon',
#  'Mandarina',
#  'Mango',
#  'Mara̱on',
#  'Melina',
#  'Musacea',
#  'Naranja',
#  'Otra variedad',
#  'Pachaco',
#  'Roble',
#  'Sapote',
#  'Teca',
#  'Variedad bifurcada',
#  'Yafruit']
